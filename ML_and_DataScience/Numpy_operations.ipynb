# %%
#IRIS
# 1. Reading tabular data
# 2. Viewing data
# 3. Selection of data
# 4. Filtering Data
# 5. Filtering missing data
# 6. Manipulating Data
# 7. Sorting Data
# 8. Grouping Data
# 9. Rearranging Data
# 10. Ranking Data
# 11. Plotting Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
edu = pd.read_csv('dataset_prg7.csv')
edu
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
edu.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
edu.tail()
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
edu.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
edu[1:20]
# Out:
#     5.1  3.5  1.4  0.2  Iris-setosa
# 1   4.7  3.2  1.3  0.2  Iris-setosa
# 2   4.6  3.1  1.5  0.2  Iris-setosa
# 3   5.0  3.6  1.4  0.2  Iris-setosa
# 4   5.4  3.9  1.7  0.4  Iris-setosa
# 5   4.6  3.4  1.4  0.3  Iris-setosa
# 6   5.0  3.4  1.5  0.2  Iris-setosa
# 7   4.4  2.9  1.4  0.2  Iris-setosa
# 8   4.9  3.1  1.5  0.1  Iris-setosa
# 9   5.4  3.7  1.5  0.2  Iris-setosa
# 10  4.8  3.4  1.6  0.2  Iris-setosa
# 11  4.8  3.0  1.4  0.1  Iris-setosa
# 12  4.3  3.0  1.1  0.1  Iris-setosa
# 13  5.8  4.0  1.2  0.2  Iris-setosa
# 14  5.7  4.4  1.5  0.4  Iris-setosa
# 15  5.4  3.9  1.3  0.4  Iris-setosa
# 16  5.1  3.5  1.4  0.3  Iris-setosa
# 17  5.7  3.8  1.7  0.3  Iris-setosa
# 18  5.1  3.8  1.5  0.3  Iris-setosa
# 19  5.4  3.4  1.7  0.2  Iris-setosa

# %%
edu['3.5']
# Out:
# 0      3.0
# 1      3.2
# 2      3.1
# 3      3.6
# 4      3.9
#       ...
# 144    3.0
# 145    2.5
# 146    3.0
# 147    3.4
# 148    3.0
# Name: 3.5, Length: 149, dtype: float64

# %%
x = edu[edu['3.5']>3.6]
table = pd.DataFrame(x, columns = ['3.5'])
print(table)
# Out:
#      3.5
# 4    3.9
# 9    3.7
# 13   4.0
# 14   4.4
# 15   3.9
# 17   3.8
# 18   3.8
# 20   3.7
# 31   4.1
# 32   4.2
# 43   3.8
# 45   3.8
# 47   3.7
# 116  3.8
# 130  3.8

# %%
pd.isnull(edu)
# Out:
#        5.1    3.5    1.4    0.2  Iris-setosa
# 0    False  False  False  False        False
# 1    False  False  False  False        False
# 2    False  False  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# ..     ...    ...    ...    ...          ...
# 144  False  False  False  False        False
# 145  False  False  False  False        False
# 146  False  False  False  False        False
# 147  False  False  False  False        False
# 148  False  False  False  False        False
#
# [149 rows x 5 columns]

# %%
new_data = edu['3.5']/100
new_data.head()
# Out:
# 0    0.030
# 1    0.032
# 2    0.031
# 3    0.036
# 4    0.039
# Name: 3.5, dtype: float64

# %%
new_data = edu['3.5'].apply(np.sqrt)
new_data
# Out:
# 0      1.732051
# 1      1.788854
# 2      1.760682
# 3      1.897367
# 4      1.974842
#          ...
# 144    1.732051
# 145    1.581139
# 146    1.732051
# 147    1.843909
# 148    1.732051
# Name: 3.5, Length: 149, dtype: float64

# %%
new_data = edu['3.5'].apply(lambda d: d ** 2)
new_data
# Out:
# 0       9.00
# 1      10.24
# 2       9.61
# 3      12.96
# 4      15.21
#        ...
# 144     9.00
# 145     6.25
# 146     9.00
# 147    11.56
# 148     9.00
# Name: 3.5, Length: 149, dtype: float64

# %%
edu['new_data']= new_data /new_data.max()
edu.tail()
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa  new_data
# 144  6.7  3.0  5.2  2.3  Iris-virginica  0.464876
# 145  6.3  2.5  5.0  1.9  Iris-virginica  0.322831
# 146  6.5  3.0  5.2  2.0  Iris-virginica  0.464876
# 147  6.2  3.4  5.4  2.3  Iris-virginica  0.597107
# 148  5.9  3.0  5.1  1.8  Iris-virginica  0.464876

# %%
edu.drop('new_data', axis=1, inplace=True)
edu
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
edu.sort_values(by='3.5',ascending=True, inplace=False)
edu
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
group = edu.groupby('Iris-setosa').mean()
group
# Out:
#                       5.1       3.5       1.4       0.2
# Iris-setosa
# Iris-setosa      5.004082  3.416327  1.465306  0.244898
# Iris-versicolor  5.936000  2.770000  4.260000  1.326000
# Iris-virginica   6.588000  2.974000  5.552000  2.026000

# %%
group1 = edu[['3.5','5.1']].groupby('5.1').mean()
group1.head()
# Out:
#           3.5
# 5.1
# 4.3  3.000000
# 4.4  3.033333
# 4.5  2.300000
# 4.6  3.325000
# 4.7  3.200000

# %%
filter_data = edu[edu['1.4']>6]
pivedu = pd.pivot_table(filter_data, values='5.1', index='3.5', columns='1.4')
pivedu
# Out:
# 1.4  6.1  6.3  6.4  6.6  6.7  6.9
# 3.5
# 2.6  NaN  NaN  NaN  NaN  NaN  7.7
# 2.8  7.4  NaN  NaN  NaN  7.7  NaN
# 2.9  NaN  7.3  NaN  NaN  NaN  NaN
# 3.0  7.7  NaN  NaN  7.6  NaN  NaN
# 3.6  7.2  NaN  NaN  NaN  NaN  NaN
# 3.8  NaN  NaN  7.9  NaN  7.7  NaN

# %%
group
# Out:
#                       5.1       3.5       1.4       0.2
# Iris-setosa
# Iris-setosa      5.004082  3.416327  1.465306  0.244898
# Iris-versicolor  5.936000  2.770000  4.260000  1.326000
# Iris-virginica   6.588000  2.974000  5.552000  2.026000

# %%
#pivedu.rank(axis=0)
group.rank(axis=0)
# Out:
#                  5.1  3.5  1.4  0.2
# Iris-setosa
# Iris-setosa      1.0  3.0  1.0  1.0
# Iris-versicolor  2.0  1.0  2.0  2.0
# Iris-virginica   3.0  2.0  3.0  3.0

# %%
#plot = edu[['5.1','3.5', '1.4', '0.2']].sum(axis=0)
#plot.plot(kind='bar', title="sum")
group.plot(kind='bar', title='Iris-setosa')
# Out:
# <Axes: title={'center': 'Iris-setosa'}, xlabel='Iris-setosa'>
